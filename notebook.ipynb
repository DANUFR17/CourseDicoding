# %% [markdown]
# # Proyek Analisis Data: Bike Sharing Dataset
# - **Nama:** Muhammad Danu Firjatullah Rachman
# - **Email:** m012d4ky2478@bangkit.academy
# - **ID Dicoding:** danufrboy_17

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# 1. Apakah ada korelasi antara musim dan jumlah sewa sepeda harian?
# 2. Apakah terdapat pola yang dapat diamati berdasarkan waktu, seperti bulan atau jam, terhadap jumlah peminjaman sepeda harian?
# 3. Bagaimana pengaruh cuaca terhadap jumlah sewa sepeda harian?
# 4. Apakah ada perbedaan antara hari kerja dan hari libur dalam jumlah sewa sepeda harian?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#menyiapkan semua library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
import os
for dirname, _, filenames in os.walk('/content/Bike_Sharing Dataset'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /content/Bike_Sharing Dataset/hour.csv
# /content/Bike_Sharing Dataset/Readme.txt
# /content/Bike_Sharing Dataset/day.csv

# %%
#membaca dataset
hour = pd.read_csv("/content/Bike_Sharing Dataset/hour.csv")
print(hour.shape)
hour.head()
# Out:
# (17379, 17)
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
day = pd.read_csv("/content/Bike_Sharing Dataset/day.csv")
print(day.shape)
day.head()
# Out:
# (731, 16)
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
#menghitung jumlah baris setiap DataFrame
print("Jumlah baris di DataFrame day:", day.shape[0])
print("Jumlah baris di DataFrame hour:", hour.shape[0])
# Out:
# Jumlah baris di DataFrame day: 731
# Jumlah baris di DataFrame hour: 17379

# %% [markdown]
# **Menggabungkan data dalam beberapa dataframe**

# %%
bike_sharing = day.merge(hour, on='dteday', how='inner', suffixes=('_daily', '_hourly'))
print(bike_sharing.shape)
# df_product.head()
bike_sharing.loc[bike_sharing["dteday"].isnull()]
bike_sharing.head()
# Out:
# (17379, 32)
#    instant_daily      dteday  season_daily  yr_daily  mnth_daily  \
# 0              1  2011-01-01             1         0           1
# 1              1  2011-01-01             1         0           1
# 2              1  2011-01-01             1         0           1
# 3              1  2011-01-01             1         0           1
# 4              1  2011-01-01             1         0           1
#
#    holiday_daily  weekday_daily  workingday_daily  weathersit_daily  \
# 0              0              6                 0                 2
# 1              0              6                 0                 2
# 2              0              6                 0                 2
# 3              0              6                 0                 2
# 4              0              6                 0                 2
#
#    temp_daily  ...  weekday_hourly  workingday_hourly  weathersit_hourly  \
# 0    0.344167  ...               6                  0                  1
# ...

# %% [markdown]
# ### Assessing Data

# %%
#memeriksa DataFrame
hour.info()
day.info()
bike_sharing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB
# ...

# %%
print(bike_sharing.shape)
bike_sharing.isnull().sum()
# Out:
# (17379, 32)
# instant_daily        0
# dteday               0
# season_daily         0
# yr_daily             0
# mnth_daily           0
# holiday_daily        0
# weekday_daily        0
# workingday_daily     0
# weathersit_daily     0
# temp_daily           0
# atemp_daily          0
# hum_daily            0
# windspeed_daily      0
# casual_daily         0
# registered_daily     0
# cnt_daily            0
# instant_hourly       0
# season_hourly        0
# yr_hourly            0
# mnth_hourly          0
# hr                   0
# holiday_hourly       0
# weekday_hourly       0
# workingday_hourly    0
# weathersit_hourly    0
# temp_hourly          0
# atemp_hourly         0
# hum_hourly           0
# windspeed_hourly     0
# casual_hourly        0
# registered_hourly    0
# cnt_hourly           0
# dtype: int64

# %% [markdown]
# ### Cleaning Data

# %%
print("Jumlah duplikasi: ", bike_sharing.duplicated().sum())
bike_sharing.describe()
# Out:
# Jumlah duplikasi:  0
#        instant_daily  season_daily      yr_daily    mnth_daily  holiday_daily  \
# count   17379.000000  17379.000000  17379.000000  17379.000000   17379.000000
# mean      367.172622      2.501640      0.502561      6.537775       0.028770
# std       210.072051      1.106918      0.500008      3.438776       0.167165
# min         1.000000      1.000000      0.000000      1.000000       0.000000
# 25%       185.000000      2.000000      0.000000      4.000000       0.000000
# 50%       367.000000      3.000000      1.000000      7.000000       0.000000
# 75%       549.000000      3.000000      1.000000     10.000000       0.000000
# max       731.000000      4.000000      1.000000     12.000000       1.000000
#
#        weekday_daily  workingday_daily  weathersit_daily    temp_daily  \
# count   17379.000000      17379.000000      17379.000000  17379.000000
# mean        3.003683          0.682721          1.391680      0.496987
# ...

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
# mendefinisikan fungsi yang akan digunakan untuk EDA
def range(series):
    return series.max() - series.min()

# %%
bike_sharing.describe(include="all")
# Out:
#         instant_daily      dteday  season_daily      yr_daily    mnth_daily  \
# count    17379.000000       17379  17379.000000  17379.000000  17379.000000
# unique            NaN         731           NaN           NaN           NaN
# top               NaN  2011-01-01           NaN           NaN           NaN
# freq              NaN          24           NaN           NaN           NaN
# mean       367.172622         NaN      2.501640      0.502561      6.537775
# std        210.072051         NaN      1.106918      0.500008      3.438776
# min          1.000000         NaN      1.000000      0.000000      1.000000
# 25%        185.000000         NaN      2.000000      0.000000      4.000000
# 50%        367.000000         NaN      3.000000      1.000000      7.000000
# 75%        549.000000         NaN      3.000000      1.000000     10.000000
# max        731.000000         NaN      4.000000      1.000000     12.000000
#
# ...

# %% [markdown]
# ### Explore ...

# %%
bike_sharing.groupby(by="season_hourly").agg({
    "workingday_hourly": "count", #menjumlahkan penyewa pada hari kerja berdasarkan musim
    "windspeed_hourly": ["max", "min", "mean", lambda x: x.max() - x.min()]  # Membuat fungsi kustom untuk range
}).sort_values(by=("workingday_hourly", "count"), ascending=False)
# Out:
#               workingday_hourly windspeed_hourly
#                           count              max  min      mean <lambda_0>
# season_hourly
# 3                          4496           0.8507  0.0  0.171593     0.8507
# 2                          4409           0.7164  0.0  0.203410     0.7164
# 1                          4242           0.8060  0.0  0.215107     0.8060
# 4                          4232           0.6418  0.0  0.170819     0.6418

# %%
bike_sharing.groupby(by="season_daily").agg({
    "workingday_daily": "count", #menjumlahkan penyewa pada hari kerja berdasarkan musim
    "windspeed_daily": ["max", "min", "mean", lambda x: x.max() - x.min()]  # Membuat fungsi kustom untuk range
}).sort_values(by=("workingday_daily", "count"), ascending=False)
# Out:
#              workingday_daily windspeed_daily
#                         count             max       min      mean <lambda_0>
# season_daily
# 3                        4496        0.375617  0.064071  0.171593   0.311546
# 2                        4409        0.388067  0.065929  0.203410   0.322138
# 1                        4242        0.507463  0.045408  0.215107   0.462055
# 4                        4232        0.422275  0.022392  0.170819   0.399883

# %%
bike_sharing.groupby(by="season_daily").mnth_daily .nunique()
# Out:
# season_daily
# 1    4
# 2    4
# 3    4
# 4    4
# Name: mnth_daily, dtype: int64

# %%
bike_sharing.groupby(by="season_daily").instant_daily.nunique()
# Out:
# season_daily
# 1    181
# 2    184
# 3    188
# 4    178
# Name: instant_daily, dtype: int64

# %%
bike_sharing.groupby(by="season_daily").cnt_daily.nunique()
# Out:
# season_daily
# 1    179
# 2    182
# 3    188
# 4    176
# Name: cnt_daily, dtype: int64

# %%
bike_sharing.groupby(by="season_daily").cnt_hourly.nunique()
# Out:
# season_daily
# 1    482
# 2    721
# 3    760
# 4    690
# Name: cnt_hourly, dtype: int64

# %%
bike_sharing.groupby(by="weathersit_daily").cnt_hourly.nunique()
# Out:
# weathersit_daily
# 1    841
# 2    686
# 3    187
# Name: cnt_hourly, dtype: int64

# %%
bike_sharing.groupby(by="weathersit_daily").cnt_daily.nunique()
# Out:
# weathersit_daily
# 1    451
# 2    243
# 3     21
# Name: cnt_daily, dtype: int64

# %% [markdown]
# **Korelasi**

# %%
numerical_columns = ["holiday_daily"
 ,"weekday_daily","workingday_daily","weathersit_daily","temp_daily","atemp_daily","season_daily", "windspeed_daily",  "cnt_daily"]
correlation = bike_sharing[numerical_columns].corr()
print(correlation)
# Out:
#                   holiday_daily  weekday_daily  workingday_daily  \
# holiday_daily          1.000000      -0.102088         -0.252471
# weekday_daily         -0.102088       1.000000          0.035955
# workingday_daily      -0.252471       0.035955          1.000000
# weathersit_daily      -0.033653       0.035082          0.057122
# temp_daily            -0.028856      -0.001894          0.058460
# atemp_daily           -0.032770      -0.009333          0.057839
# season_daily          -0.009585      -0.002335          0.013743
# windspeed_daily        0.006319       0.018226         -0.018746
# cnt_daily             -0.070344       0.064204          0.068216
#
#                   weathersit_daily  temp_daily  atemp_daily  season_daily  \
# holiday_daily            -0.033653   -0.028856    -0.032770     -0.009585
# weekday_daily             0.035082   -0.001894    -0.009333     -0.002335
# workingday_daily          0.057122    0.058460     0.057839      0.013743
# ...

# %% [markdown]
# Jumlah penyewa sepeda menunjukkan korelasi negatif dengan hari libur, kondisi cuaca, dan kecepatan angin, yang berarti bahwa ketika ada lebih banyak hari libur, cuaca buruk, atau kecepatan angin tinggi, jumlah penyewa sepeda cenderung menurun.

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Apakah ada korelasi antara musim dan jumlah sewa sepeda harian?

# %%
seasonal_data = bike_sharing.groupby('season_daily')['cnt_daily'].mean()
season_names = ['Spring', 'Summer', 'Fall', 'Winter']
plt.bar(season_names, seasonal_data)
plt.xlabel('Musim')
plt.ylabel('Rata-rata Jumlah Sewa Harian')
plt.title('Pengaruh Musim Terhadap Jumlah Sewa Sepeda Harian')
plt.show()

# %% [markdown]
# ### Pertanyaan 2: Apakah ada pola berdasarkan waktu dalam jumlah sewa sepeda harian?

# %%
# Pola berdasarkan bulan
sns.set_style("whitegrid")
plt.figure(figsize=(12, 6))
sns.lineplot(x="mnth_daily", y="cnt_daily", data=bike_sharing, ci=None)
plt.title("Pola Jumlah Sewa Sepeda Harian Berdasarkan Bulan")
plt.xlabel("Bulan")
plt.ylabel("Jumlah Sewa Sepeda Harian")
plt.show()

# %%
# Pola berdasarkan jam
sns.set_style("whitegrid")
plt.figure(figsize=(12, 6))
sns.lineplot(x="hr", y="cnt_hourly", data=bike_sharing, ci=None)
plt.title("Pola Jumlah Sewa Sepeda Harian Berdasarkan Jam")
plt.xlabel("Jam")
plt.ylabel("Jumlah Sewa Sepeda Harian")
plt.show()

# %% [markdown]
# Berdasarkan deskripsi yang Anda berikan, terdapat dua grafik yang menunjukkan pola waktu sewa sepeda. Waktu sewa lebih banyak terjadi pada bulan Juni dan September, sementara jumlah sewa sepeda meningkat sekitar jam 8 pagi dan sekitar jam 5 atau 6 sore.

# %% [markdown]
# Pertanyaan 3: Bagaimana pengaruh cuaca terhadap jumlah sewa sepeda harian?

# %%
# Pengaruh Weathersit
plt.figure(figsize=(10, 6))
sns.boxplot(x="weathersit_daily", y="cnt_daily", data=bike_sharing)
plt.title("Pengaruh Weathersit Terhadap Jumlah Sewa Sepeda Harian")
plt.xlabel("Weathersit")
plt.ylabel("Jumlah Sewa Sepeda Harian")
plt.show()

# %% [markdown]
# jumlah sewa sepeda mengingkat ketika cuaca Cerah, Sedikit awan, Berawan sebagian, Berawan sebagian

# %% [markdown]
# Pertanyaan 4: Apakah ada perbedaan antara hari kerja dan hari libur dalam jumlah sewa sepeda harian?

# %%
# Perbandingan hari kerja dan hari libur
plt.figure(figsize=(8, 5))
sns.boxplot(x="workingday_daily", y="cnt_daily", data=bike_sharing)
plt.title("Perbedaan Antara Hari Kerja dan Hari Libur dalam Jumlah Sewa Sepeda Harian")
plt.xlabel("Workingday")
plt.ylabel("Jumlah Sewa Sepeda Harian")
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Apakah ada korelasi antara musim dan jumlah sewa sepeda harian?
# - Apakah terdapat pola yang dapat diamati berdasarkan waktu, seperti bulan atau jam, terhadap jumlah peminjaman sepeda harian?
# - Bagaimana pengaruh cuaca terhadap jumlah sewa sepeda harian?
# - Apakah ada perbedaan antara hari kerja dan hari libur dalam jumlah sewa sepeda harian?

# %% [markdown]
# - Ada korelasi dengan jumlah sewa sepeda lebih banyak pada musim gugur.
# - Ada jumlah sewa sepeda meningkat pada bulan 9 dan 6. jika berdasarkan jam jumlah sewa sepeda meningkat sekitar jam 8 pagi dan sekitar jam 5 atau 6 sore.
# - Cuaca mempengaruhi jumlah sewa sepeda mengingkat ketika cuaca Cerah, Sedikit awan, Berawan sebagian, Berawan sebagian.
# - Ada perbedaan jumlah sewa sepeda lebih banyak ketika hari kerja daipada hari libur.
